# %% [markdown]
# #  nbpresent

# %%
from bokeh.sampledata.iris import flowers
from bokeh.plotting import figure, show, output_notebook
output_notebook()
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>

# %%
colormap = {'setosa': 'red', 'versicolor': 'green', 'virginica': 'blue'}
flowers['color'] = flowers['species'].map(lambda x: colormap[x])

p = figure(title="Iris Morphology", width=1000, height=700)
p.xaxis.axis_label = 'Petal Length'
p.yaxis.axis_label = 'Petal Width'

p.circle(flowers["petal_length"], flowers["petal_width"],
        color=flowers["color"], fill_alpha=0.2, size=10, )

show(p);
# Out:
#     <div class="plotdiv" id="f7cdcb43-b6c3-420b-8fa2-62b02f97e4fc"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f7cdcb43-b6c3-420b-8fa2-62b02f97e4fc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f7cdcb43-b6c3-420b-8fa2-62b02f97e4fc' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"0362245d-e287-4ba1-980f-83fcefcc8433": {"title": "Bokeh Application", "version": "0.11.0", "roots": {"references": [{"id": "025036d9-635a-4ad8-8697-3a65039a95d5", "type": "Grid", "attributes": {"plot": {"id": "1b047792-0ec5-40b0-9aae-50d80579106c", "type": "Plot", "subtype": "Figure"}, "dimension": 1, "ticker": {"id": "6356dab3-3d95-4e38-8914-67ac979d9ef2", "type": "BasicTicker"}}}, {"id": "82e37e1b-bc9a-4720-9098-7da76caf81e1", "type": "Circle", "attributes": {"y": {"field": "y"}, "line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "size": {"value": 10, "units": "screen"}}}, {"id": "fab8447c-2059-4fa1-a2f0-b81804f6b400", "type": "LinearAxis", "attributes": {"plot": {"id": "738b1e26-bd09-47bc-a66f-81d110b4855f", "type": "Plot", "subtype": "Figure"}, "axis_label": "Petal Width", "ticker": {"id": "fb700f1e-48a5-4643-a28d-816ef96bfe16", "type": "BasicTicker"}, "formatter": {"id": "dabb053d-8a6c-4aa7-8b73-33085f0337ad", "type": "BasicTickFormatter"}}}, {"id": "8da811e6-7e6d-47c4-8416-3c16d34e468d", "type": "Grid", "attributes": {"plot": {"id": "a9555fe2-9385-4a3e-bf6f-065a4621d84f", "type": "Plot", "subtype": "Figure"}, "ticker": {"id": "e38e6969-1fe6-4390-97b8-7c88a0589967", "type": "BasicTicker"}}}, {"id": "f6ff48ed-a4ba-4ca7-9ea6-2f9f5272cf2e", "type": "BasicTicker", "attributes": {}}, {"id": "911b182f-6c7c-4ad1-a6cf-ec64b72fd8bf", "type": "BasicTicker", "attributes": {}}, {"id": "559acddf-5499-4d84-b606-df015542deec", "type": "GlyphRenderer", "attributes": {"selection_glyph": null, "glyph": {"id": "fd6bc8d5-4573-455c-b1c5-ca6ba7d22961", "type": "Circle"}, "nonselection_glyph": {"id": "82e37e1b-bc9a-4720-9098-7da76caf81e1", "type": "Circle"}, "data_source": {"id": "08a72129-a4d7-4447-9327-6d8289b05db7", "type": "ColumnDataSource"}, "hover_glyph": null}}, {"id": "4405f954-131a-4984-b559-fc5ec0debfec", "type": "Circle", "attributes": {"y": {"field": "y"}, "line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "size": {"value": 10, "units": "screen"}}}, {"id": "74f0738e-39b5-4243-b5c9-62b80acefe3e", "type": "Grid", "attributes": {"plot": {"id": "a9555fe2-9385-4a3e-bf6f-065a4621d84f", "type": "Plot", "subtype": "Figure"}, "dimension": 1, "ticker": {"id": "e10a1c9f-7956-495f-ac4b-98dd6eabca89", "type": "BasicTicker"}}}, {"id": "738b1e26-bd09-47bc-a66f-81d110b4855f", "type": "Plot", "attributes": {"plot_height": 800, "y_range": {"id": "137ac841-c70d-4888-90c8-dfad177190a6", "type": "DataRange1d"}, "title": "Iris Morphology", "renderers": [{"id": "8f3f0551-0cc3-4660-b136-33e317792f09", "type": "LinearAxis"}, {"id": "66ce02a9-5d2b-40de-a441-9e8a91c031f5", "type": "Grid"}, {"id": "fab8447c-2059-4fa1-a2f0-b81804f6b400", "type": "LinearAxis"}, {"id": "a4480424-0afa-4ce3-9fa8-154c9f866e00", "type": "Grid"}, {"id": "19bf9d84-873a-4091-a17b-03324e8a7a4c", "type": "BoxAnnotation"}, {"id": "fbfbb569-0f7a-4706-938f-78c39c2c7f8b", "type": "GlyphRenderer"}], "left": [{"id": "fab8447c-2059-4fa1-a2f0-b81804f6b400", "type": "LinearAxis"}], "x_range": {"id": "9a98aa6d-4ab7-4211-bb87-b464fafc225c", "type": "DataRange1d"}, "tools": [{"id": "4121a933-a730-4931-929f-8b20e6b4ecb5", "type": "PanTool"}, {"id": "1006bef1-4c24-49c3-ab4d-7f92bac109f5", "type": "WheelZoomTool"}, {"id": "f8a19754-4bc2-4f06-b79d-93b05229c3a6", "type": "BoxZoomTool"}, {"id": "26c038bb-55d6-4f27-8b3f-d4c0b3fc1f6d", "type": "PreviewSaveTool"}, {"id": "96a2df12-93b2-4952-ace8-2c8fda9d7311", "type": "ResizeTool"}, {"id": "f2921bc1-d2ae-49bd-bc0b-115ca78fc7a1", "type": "ResetTool"}, {"id": "f7435b96-1efd-42b8-87c8-1ea568e471e8", "type": "HelpTool"}], "below": [{"id": "8f3f0551-0cc3-4660-b136-33e317792f09", "type": "LinearAxis"}], "tool_events": {"id": "37e27d45-89e6-4950-b95a-b284c51ec78b", "type": "ToolEvents"}, "plot_width": 1200}, "subtype": "Figure"}, {"id" ...

# %%
from ipywidgets import widgets
import numpy as np  
import matplotlib.pyplot as plt
import pandas
import qgrid
qgrid.nbinstall(overwrite=True)
qgrid.set_defaults(remote_js=True, precision=4)

# %%
# %matplotlib inline

# %%
@widgets.interact
def graph(a=10.0, b=2.0):
    x = np.array(range(-100, 100))/100
    y = np.sin((a * x)**b)
    plt.figure(figsize=(16,9))
    plt.plot(x, y)
    plt.show()

# %%
df = pandas.DataFrame(
    np.random.randn(100, 3)
)

# %%
qgrid.show_grid(df)
# Out:
# <script type="text/javascript">
# if ($("#dg-css").length == 0){
#     $("head").append([
#         "<link href='https://cdn.rawgit.com/quantopian/qgrid/72d356cb123fab413dba73ec46616e4916fbd827/qgrid/qgridjs//lib/slick.grid.css' rel='stylesheet'>",
#         "<link href='https://cdn.rawgit.com/quantopian/qgrid/72d356cb123fab413dba73ec46616e4916fbd827/qgrid/qgridjs//lib/slick-default-theme.css' rel='stylesheet'>",
#         "<link href='http://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.4/css/jquery-ui.min.css' rel='stylesheet'>",
#         "<link id='dg-css' href='https://cdn.rawgit.com/quantopian/qgrid/72d356cb123fab413dba73ec46616e4916fbd827/qgrid/qgridjs//qgrid.css' rel='stylesheet'>"
#     ]);
# }
# </script>
# <div class='q-grid-container'>
# <div id='3e8913b1-4fbb-480d-b878-3926b83e0ef3' class='q-grid'></div>
# </div>

# %%
qgrid.show_grid(df.describe())
# Out:
# <script type="text/javascript">
# if ($("#dg-css").length == 0){
#     $("head").append([
#         "<link href='https://cdn.rawgit.com/quantopian/qgrid/72d356cb123fab413dba73ec46616e4916fbd827/qgrid/qgridjs//lib/slick.grid.css' rel='stylesheet'>",
#         "<link href='https://cdn.rawgit.com/quantopian/qgrid/72d356cb123fab413dba73ec46616e4916fbd827/qgrid/qgridjs//lib/slick-default-theme.css' rel='stylesheet'>",
#         "<link href='http://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.4/css/jquery-ui.min.css' rel='stylesheet'>",
#         "<link id='dg-css' href='https://cdn.rawgit.com/quantopian/qgrid/72d356cb123fab413dba73ec46616e4916fbd827/qgrid/qgridjs//qgrid.css' rel='stylesheet'>"
#     ]);
# }
# </script>
# <div class='q-grid-container'>
# <div id='d20d7e3a-13b6-49fc-919d-6c2c6aa96a5c' class='q-grid'></div>
# </div>
